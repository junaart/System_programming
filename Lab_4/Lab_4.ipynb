# %% [markdown]
# # Лабораторная работа №4. Вычисления с использованием языка ассемблера

# %% [markdown]
# На языке ассемблера и на языке С разработать программы, решаюшие задачи в соответствии с вариантом. На языке ассемблера ввод параметров в программу реализовать через **системный вызов read**.

# %% [markdown]
# **Перечень задач**
#
# 1. Написать программу, которая для заданного $n$ позволяет определить, сколько целых чисел между 1 и $n$ делятся одновременно на 37 и 13.
# 2. Написать программу, которая для заданного $n$ вычисляет сумму: $$1-2^2+3^2-4^2+5^2-\ldots+(-1)^{n-1}n^2$$
# 3. Написать программу, которая для заданного $n$ вычисляет сумму: $$\sum_{k=1}^{n}(-1)^k k(k+1)(3k+1)(3k+2)$$
# 4. Написать программу, которая для заданного $n$ вычисляет сумму:$$\sum_{k=1}^{n}(-1)^k\cdot k(k+4)(k+8)$$
# 5. Написать программу, которая для заданного $n$ позволяет определить, сколько целых чисел между 1 и $n$ не делятся на 11 или на  5.
# 6. Написать программу, которая для заданного $n$ позволяет определить, сколько целых чисел между 1 и $n$ не делятся на 3 и 7, но делятся на  5.
# 7. Реализовать функцию, которая для заданного $n$ получает число из цифр числа $n$, записанных в обратном порядке.
# 8. Реализовать функцию, которая для заданного $n$ получает число из его цифр, чередующихся через нуль. Например, если $n=123$, то функция должна выдавать $102030$.
# 9. Для заданного $n$ вычислить сумму $$1+2-3-4+5+6-7-8\ldots\pm n$$
# 10. Разработать программу аутентификации пользователя: вводится пароль. Если пароль неверен, выдается сообщение «Невереный пароль» и пароль вводится снова. Повтор допускается до 5 раз. Если правильный пароль так и не будет введен, выдается сообщение "Неудача", если пароль подобран, то выдается сообщение "Вошли"
# 11. Команда из $n$ судей принимает решение большинством голосов. Каждый судья должен проголосовать, ответив "Да" (1), или "Нет" (0). Реализовать программу, которая помогает судьям принять окончательное решение.
# 12. Реализовать функцию, которая для заданного числа $n$ определяет, что все его цифры следуют в неубывающем порядке. Например, для числа $n=1489$ - это так, а для $n=4632$ - нет.
# 13. Найти все числа, не превосходящие заданного $n$ и делящиеся на две своих последних цифры.
# 14. Найти все числа от 1 до $n$, которые совпадают с последними разрядами своих квадратов. Например, $25^2 = 625, 76^2 = 5676$

# %%
import random as rd

Variant = 1
rd.seed(Variant)

Numbers_of_problems = [i+1 for i in rd.sample(range(14),3)]
Numbers_of_problems
# Out:
# [3, 10, 2]
