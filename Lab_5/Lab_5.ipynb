# %% [markdown]
# # Лабораторная работа №5. Работа с файлами в Linux средствами ассемблера

# %% [markdown]
# На языке ассемблера разработать программы, решаюшие задачи в соответствии с вариантом.

# %% [markdown]
# 1. Реализовать программу, в которой для заданного текстового файла (латиница) производится подсчет количества букв, цифр. Результат подсчета записать во второй файл в формате:
# - **number of letters:...**
# - **number of digits:...**
#
# Имена файлов передавать параметрами командной строки.
#
# 2. Из заданного текстового файла (латиница) прочитать каждый $k$-й символ, результат записать во второй файл. Имена файлов, значение $k$ передавать параметрами командной строки.
# 3. Для заданного текстового файла (латиница) прочитать все строки (строка заканчивается символом разрыва строки $0x0a$) и записать их во второй файл в обратном порядке: первая строка первого файла должна стать последней во втором и т.д. Имена файлов передавать параметрами командной строки.
# 4. Для заданного текстового файла (латиница) переписать во второй файл весь текст без гласных букв: «A», «E», «I», «O», «U», «Y» (верхнего регистра). Имена файлов передавать параметрами командной строки.
# 5. Для заданного текстового файла(латиница) и заданной позиции в файле $k$ записать во второй файл символы из первого в следующем "раскачивающемся" порядке: $$(k-m), (k-m+1), (k-m+2), \ldots, (k-1), k, (k+1), \ldots, (k+m-2), (k+m-1), (k+m)$$ Имена файлов, значения $k, m $ передавать параметрами командной строки.
# 6. Для заданного текстового файла (латиница) все согласные буквы: «B», «C», «D», «F», «G», «H», «J», «K», «L», «M», «N», «P», «Q», «R», «S», «T», «V», «W», «X», «Y», «Z» (верхнего и нижнего регистра) удвоить, результат записать во второй файл. Имена файлов передавать параметрами командной строки.
# 7. Для заданного текстового файла каждую букву заменить на другую, ASCII-код которой сдвинут на $k$ позиций справо. Результат записать во второй файл. Разработать вторую программу, которая выполнячет обратное преобразование, восстанавливая исходный текст (реализуя тем самым своеобразный [шифр Цезаря](https://ru.wikipedia.org/wiki/%D0%A8%D0%B8%D1%84%D1%80_%D0%A6%D0%B5%D0%B7%D0%B0%D1%80%D1%8F)). Имена файлов, значение $k$ передавать параметрами командной строки.
# 8. Для двух текстовых файлов в третий файл записать все символы, которые встречаются как в первом, так и во втором. Имена файлов передавать параметрами командной строки.
# 9. Для заданного текстового файла записать во второй файл только числа, которые встречаются в первом файле. Имена файлов передавать параметрами командной строки.
# 10. Для заданного текстового файла во второй файл каждое предложение (заканчивается ., !, ?) записать задом наперед. Имена файлов передавать параметрами командной строки.
# 11. Для заданного $n$ записать в файл все простые числа от 1 до $n$. После этого оставить только простые числа, заканчивающиеся на единицу. Имена файлов и значение $n$ вводится с клавиатуры.

# %%
import random as rd

Variant = 1
rd.seed(Variant)

Numbers_of_problems = [i+1 for i in rd.sample(range(11),2)]
Numbers_of_problems
# Out:
# [3, 10]
